# %% [markdown]
# # TTS-with-RVC Google Colab example

# %% [markdown]
# 1. Install deps

# %%
# !pip install torch --index-url https://download.pytorch.org/whl/cu126
# !pip install git+https://github.com/Atm4x/tts-with-rvc.git@#egg=tts_with_rvc

# %% [markdown]
# 2. Write file with your code

# %%
# %%writefile main.py
from tts_with_rvc import TTS_RVC

tts = TTS_RVC(
    model_path="/content/models/DenVot13800.pth",
    input_directory="input\\"
)
# Do not forget to change tts voice for Male/Female characters
tts.set_voice("ru-RU-DmitryNeural")
path = tts(text="Привет, Мир!", pitch=6, index_rate=0.9)
print(path)
# Out:
# Overwriting main.py

# %% [markdown]
# 3. Upload .pth file

# %% [markdown]
# 4. Run the script

# %%
# !python main.py
# Out:
# 2025-03-28 16:14:55.483336: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743178495.518887    8534 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743178495.527238    8534 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-28 16:14:55.560104: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
